# %% [markdown]
# Develop the process to download (only) the English book texts using Python. Find a suitable way to store the results for further processing (which you will do in assignment 2), e.g. saving the downloaded documents to a dedicated folder.
# Besides the documents, you need to store some properties of all downloaded documents. You should at least store the following properties of the downloaded documents as shown on the website:
#
# ### Property
# - URL (of plaintext version)
# - Title
# - Author
# - Reading Level
# - EBook-No.
# - Language
# - Most Recently Updated
#
#
# ### To Do:
# 1. eerst linken naar de goede plaats: onder titel van Top 100 EBooks last 30 days, ik denk dat je dat kan zoeken door te kijken naar de titel van html ofzo? GEDAAN
# 2. daarna moeten de links geopend worden naar het boek GEDAAN
# 3. de properties moeten worden worden opgeslagen in een document GEDAAN
# 4. Er moet gecheckt worden of property compleet is (dit staat op de pagina zelf, niet in het boek), anders verwijderen uit rij. (dus ook of het engels is of niet)
# 5. boek moet worden geopend in de link 'Plain Text UTF-8' (als die er is)
# 6. de boeken moeten gedownload worden in een mapje

# %%
import re
from urllib.request import urlopen, urljoin
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %%
url = "https://books.flotwiskunde.nl/browse/scores/top.html"
page = urlopen(url)
html = page.read()

soup = BeautifulSoup(html, "html.parser")
header = soup.find("h2", id="books-last30")
book_list = header.find_next("ol")

links = []
for li in book_list.find_all("li"):
    a_tag = li.find("a")
    if a_tag:
        link = a_tag.get("href")
        full_link = urljoin(url, link)
        links.append(full_link)

book_dicts = []

for web_url in links:
    response = requests.get(web_url)
    soup = BeautifulSoup(response.text, "html.parser")
        
    table_2 = soup.find('table', class_='bibrec')
    book_info = {}
    if table_2:
        for row in table_2.find_all('tr'):
            header = row.find('th')
            value = row.find('td')
            if header and value:
                key = header.text.strip()
                val = value.text.strip()
                if key == "Title":
                    book_info["Title"] = val
                elif key == "Author":
                    book_info["Author"] = val
                elif key == "Reading Level":
                    book_info["Reading_Level"] = val
                elif key == "EBook-No.":
                    book_info["EBook_No."] = val
                elif key == "Language":
                    book_info["Language"] = val
                elif key == "Most Recently Updated":
                    book_info["Most_Recently_Updated"] = val

        book_dicts.append({
            "URL": web_url,
            "Title": book_info.get("Title", ""),
            "Author": book_info.get("Author", ""),
            "Reading_Level": book_info.get("Reading_Level", ""),
            "EBook_No.": book_info.get("EBook_No.", ""),
            "Language": book_info.get("Language", ""),
            "Most_Recently_Updated": book_info.get("Most_Recently_Updated", "")
        })

properties_books = pd.DataFrame(book_dicts)
properties_books
# Out:
#                                                 URL  \
# 0      https://books.flotwiskunde.nl/ebooks/84.html
# 1    https://books.flotwiskunde.nl/ebooks/2701.html
# 2    https://books.flotwiskunde.nl/ebooks/1342.html
# 3    https://books.flotwiskunde.nl/ebooks/1513.html
# 4   https://books.flotwiskunde.nl/ebooks/26184.html
# ..                                              ...
# 95    https://books.flotwiskunde.nl/ebooks/132.html
# 96   https://books.flotwiskunde.nl/ebooks/2814.html
# 97  https://books.flotwiskunde.nl/ebooks/75883.html
# 98  https://books.flotwiskunde.nl/ebooks/10676.html
# 99    https://books.flotwiskunde.nl/ebooks/514.html
#
#                                                 Title  \
# 0             Frankenstein; Or, The Modern Prometheus
# 1                            Moby Dick; Or, The Whale
# 2                                 Pride and Prejudice
# 3                                    Romeo and Juliet
# 4                        Simple Sabotage Field Manual
# ..                                                ...
# 95                                     The Art of War
# 96                                          Dubliners
# 97  The Roll of Honour, Volume 1 :  A biographical...
# 98                                 The Reign of Greed
# 99                                       Little Women
#
#                                                Author  \
# 0             Shelley, Mary Wollstonecraft, 1797-1851
# 1                         Melville, Herman, 1819-1891
# 2                             Austen, Jane, 1775-1817
# 3                     Shakespeare, William, 1564-1616
# 4         United States. Office of Strategic Services
# ..                                                ...
# 95                     Sunzi, active 6th century B.C.
# 96                            Joyce, James, 1882-1941
# 97  Ruvigny et Raineval, Melville Henry Massue, ma...
# 98                            Rizal, Jos̩, 1861-1896
# 99                      Alcott, Louisa May, 1832-1888
#
#                                         Reading_Level EBook_No. Language  \
# 0   Reading ease score: 65.0 (8th & 9th grade). Ne...        84  English
# 1   Reading ease score: 73.3 (7th grade). Fairly e...      2701  English
# 2   Reading ease score: 69.2 (8th & 9th grade). Ne...      1342  English
# 3   Reading ease score: 92.6 (5th grade). Very eas...      1513  English
# 4   Reading ease score: 60.5 (8th & 9th grade). Ne...     26184  English
# ..                                                ...       ...      ...
# 95  Reading ease score: 66.8 (8th & 9th grade). Ne...       132  English
# 96  Reading ease score: 81.7 (6th grade). Easy to ...      2814  English
# 97  Reading ease score: 85.9 (6th grade). Easy to ...     75883  English
# 98  Reading ease score: 66.9 (8th & 9th grade). Ne...     10676  English
# 99  Reading ease score: 77.0 (7th grade). Fairly e...       514  English
#
#    Most_Recently_Updated
# 0            Sep 8, 2025
# 1           Sep 11, 2025
# 2           Sep 22, 2025
# 3           Sep 18, 2025
# 4            Feb 5, 2025
# ..                   ...
# 95          Aug 16, 2024
# 96          May 21, 2021
# 97
# 98          Oct 28, 2024
# 99           Nov 4, 2022
#
# [100 rows x 7 columns]

# %% [markdown]
# # Bronnen
# - https://www.w3schools.com/python/python_regex.asp
# - https://realpython.com/python-web-scraping-practical-introduction/
# - https://www.slingacademy.com/article/extract-all-links-from-a-webpage-using-python-and-beautiful-soup/?utm_source=chatgpt.com
# - https://memudualimatou.medium.com/web-scraping-how-to-extract-a-table-8c979ab40c23
#
# # AI gebruik
# - Nagaan of de code goed functioneert
# - Errors verwerken
# - Gevraagd naar specifieke tutorials over bepaalde onderwerpen
# - Matchen van elke specifieke kopje van de tabel
